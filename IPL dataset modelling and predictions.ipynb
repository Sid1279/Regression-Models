# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("IPL.csv")

# %%
data
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
data.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
data.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
#obtaining a specific column
player_name = data["PLAYER NAME"]
player_name.head()
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
#neater
player_name = data[["PLAYER NAME"]]
player_name.head()
# Out:
#     PLAYER NAME
# 0   Abdulla, YA
# 1  Abdur Razzak
# 2   Agarkar, AB
# 3     Ashwin, R
# 4  Badrinath, S

# %%
type(player_name)
# Out:
# pandas.core.frame.DataFrame

# %%
#multiple columns
sub_data = data[["PLAYER NAME", "WKTS", "AUCTION YEAR"]]
sub_data #DataFrame
# Out:
#       PLAYER NAME  WKTS  AUCTION YEAR
# 0     Abdulla, YA    15          2009
# 1    Abdur Razzak     0          2008
# 2     Agarkar, AB    29          2008
# 3       Ashwin, R    49          2011
# 4    Badrinath, S     0          2011
# ..            ...   ...           ...
# 125     Yadav, AS     0          2010
# 126   Younis Khan     0          2008
# 127  Yuvraj Singh    23          2011
# 128   Zaheer Khan    65          2008
# 129    Zoysa, DNT     2          2008
#
# [130 rows x 3 columns]

# %%
type(sub_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#selecting a part that satisfies certain conditions
sixers_above_50 = data[data["SIXERS"] > 50]
sixers_above_50
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 15       16      Dhoni, MS    2     IND    CSK    W. Keeper    3509       0
# 26       27      Gayle, CH    2      WI   KKR+   Allrounder    6373      72
# 28       29  Gilchrist, AC    3     AUS    DC+    W. Keeper    5570       0
# 82       83     Pathan, YK    2     IND    RR+   Allrounder       0       0
# 88       89      Raina, SK    1     IND    CSK      Batsman     710      13
# 93       94      Sehwag, V    2     IND     DD      Batsman    8178      40
# 97       98     Sharma, RG    1     IND    DC+      Batsman       0       0
# 116     117    Uthappa, RV    2     IND   RCB+      Batsman       0       0
# 127     128   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 15         6773     88.19  ...  136.45      64       0     0    0.00   0.00
# ...

# %%
sixers_above_50.shape
#9 rows by 26 columns
# Out:
# (9, 26)

# %%
#Players from AUS and WI
country_AUS_WI = data[data["COUNTRY"].isin(["AUS", "WI"])]
country_AUS_WI
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 5         6      Bailey, GJ    2     AUS    CSK      Batsman       0       0
# 7         8   Bollinger, DE    2     AUS    CSK       Bowler      54      50
# 10       11       Bravo, DJ    2      WI    MI+   Allrounder    2200      86
# 11       12  Chanderpaul, S    3      WI    RCB      Batsman    9918       9
# 20       21     Edwards, FH    2      WI     DC       Bowler     380     157
# 26       27       Gayle, CH    2      WI   KKR+   Allrounder    6373      72
# 28       29   Gilchrist, AC    3     AUS    DC+    W. Keeper    5570       0
# 31       32      Harris, RJ    2     AUS    DC+       Bowler     199      46
# 32       33      Hayden, ML    3     AUS    CSK      Batsman    8625       0
# 34       35   Henriques, MC    1     AUS   KKR+   Allrounder       0       0
# 35       36       Hodge, BJ    3     AUS   KKR+      Batsman     503       0
# ...

# %%
#Alternative to get players from AUS and WI
country_AUS_WI = data[(data["COUNTRY"] == "AUS") | (data["COUNTRY"] == "WI")]
country_AUS_WI

#MUST use '|' not 'or'
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 5         6      Bailey, GJ    2     AUS    CSK      Batsman       0       0
# 7         8   Bollinger, DE    2     AUS    CSK       Bowler      54      50
# 10       11       Bravo, DJ    2      WI    MI+   Allrounder    2200      86
# 11       12  Chanderpaul, S    3      WI    RCB      Batsman    9918       9
# 20       21     Edwards, FH    2      WI     DC       Bowler     380     157
# 26       27       Gayle, CH    2      WI   KKR+   Allrounder    6373      72
# 28       29   Gilchrist, AC    3     AUS    DC+    W. Keeper    5570       0
# 31       32      Harris, RJ    2     AUS    DC+       Bowler     199      46
# 32       33      Hayden, ML    3     AUS    CSK      Batsman    8625       0
# 34       35   Henriques, MC    1     AUS   KKR+   Allrounder       0       0
# 35       36       Hodge, BJ    3     AUS   KKR+      Batsman     503       0
# ...

# %%
#if there are NaN
age_no_na = data[data["AGE"].notna()]

# %%
data.shape == age_no_na.shape
#no NaN present
# Out:
# True

# %%
data.iloc[0:4, 6:8]

#rows 0-4, cols 6-8
# Out:
#    T-RUNS  T-WKTS
# 0       0       0
# 1     214      18
# 2     571      58
# 3     284      31

# %%
data.plot()
plt.show()

#can use .plot() on a series or a df

# %%
data[["WKTS", "SIXERS"]].plot()
#plt.show() - optional
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter(x="WKTS", y="RUNS-C")
# Out:
# <AxesSubplot:xlabel='WKTS', ylabel='RUNS-C'>

# %%
compressed = data[["ODI-WKTS", "ODI-RUNS-S", "SIXERS", "TEAM"]]
compressed
# Out:
#      ODI-WKTS  ODI-RUNS-S  SIXERS   TEAM
# 0           0           0       0   KXIP
# 1         185         657       0    RCB
# 2         288        1269       5    KKR
# 3          51         241       0    CSK
# 4           0          79      28    CSK
# ..        ...         ...     ...    ...
# 125         0           0       2     DC
# 126         3        6814       0     RR
# 127       109        8051      67  KXIP+
# 128       278         790       1    MI+
# 129       108         343       0     DC
#
# [130 rows x 4 columns]

# %%
data[["ODI-WKTS", "WKTS"]].plot.box()
# Out:
# <AxesSubplot:>

# %%
compressed.plot.area(figsize=(12, 4), subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
compressed.plot.area(figsize=(12, 4), subplots=False)
# Out:
# <AxesSubplot:>

# %%
new_comp = compressed.rename(
    columns = {
        "ODI-WKTS": "REGULAR WKTS",
        "TEAM": "IPL TEAM"
    }
)

new_comp

#no change is made to compressed
# Out:
#      REGULAR WKTS  ODI-RUNS-S  SIXERS IPL TEAM
# 0               0           0       0     KXIP
# 1             185         657       0      RCB
# 2             288        1269       5      KKR
# 3              51         241       0      CSK
# 4               0          79      28      CSK
# ..            ...         ...     ...      ...
# 125             0           0       2       DC
# 126             3        6814       0       RR
# 127           109        8051      67    KXIP+
# 128           278         790       1      MI+
# 129           108         343       0       DC
#
# [130 rows x 4 columns]

# %%
compressed
# Out:
#      ODI-WKTS  ODI-RUNS-S  SIXERS   TEAM
# 0           0           0       0   KXIP
# 1         185         657       0    RCB
# 2         288        1269       5    KKR
# 3          51         241       0    CSK
# 4           0          79      28    CSK
# ..        ...         ...     ...    ...
# 125         0           0       2     DC
# 126         3        6814       0     RR
# 127       109        8051      67  KXIP+
# 128       278         790       1    MI+
# 129       108         343       0     DC
#
# [130 rows x 4 columns]

# %%
#converting to lowercase
compressed.rename(columns = str.lower)
# Out:
#      odi-wkts  odi-runs-s  sixers   team
# 0           0           0       0   KXIP
# 1         185         657       0    RCB
# 2         288        1269       5    KKR
# 3          51         241       0    CSK
# 4           0          79      28    CSK
# ..        ...         ...     ...    ...
# 125         0           0       2     DC
# 126         3        6814       0     RR
# 127       109        8051      67  KXIP+
# 128       278         790       1    MI+
# 129       108         343       0     DC
#
# [130 rows x 4 columns]

# %%
data[["ODI-WKTS", "ODI-RUNS-S", "SIXERS"]].median()

#can do mean, median, mode
# Out:
# ODI-WKTS       18.5
# ODI-RUNS-S    835.0
# SIXERS          6.0
# dtype: float64

# %%
compressed.describe()
# Out:
#          ODI-WKTS    ODI-RUNS-S      SIXERS
# count  130.000000    130.000000  130.000000
# mean    76.076923   2508.738462   17.692308
# std    111.205070   3582.205625   23.828146
# min      0.000000      0.000000    0.000000
# 25%      0.000000     73.250000    1.000000
# 50%     18.500000    835.000000    6.000000
# 75%    106.000000   3523.500000   29.750000
# max    534.000000  18426.000000  129.000000

# %%
compressed.agg(
    {
        "ODI-WKTS": ["min", "max", "median", "mean", "skew"],
        "ODI-RUNS-S": ["min", "max", "median", "mean", "skew"],
    }
)
# Out:
#           ODI-WKTS    ODI-RUNS-S
# min       0.000000      0.000000
# max     534.000000  18426.000000
# median   18.500000    835.000000
# mean     76.076923   2508.738462
# skew      1.797747      1.874177

# %%
compressed.groupby("ODI-WKTS").median()
# Out:
#           ODI-RUNS-S  SIXERS
# ODI-WKTS
# 0              761.0    17.5
# 1              165.0     2.0
# 2             3491.5    15.0
# 3             3432.5     0.5
# 4            10889.0    23.0
# ...              ...     ...
# 377           1100.0     6.0
# 381            115.0     0.0
# 393           3519.0     8.0
# 400           2025.0     3.0
# 534            674.0     0.0
#
# [74 rows x 2 columns]

# %%
compressed.groupby("ODI-WKTS")[["ODI-RUNS-S", "SIXERS"]].mean()
# Out:
#             ODI-RUNS-S     SIXERS
# ODI-WKTS
# 0          2136.176471  23.088235
# 1          1910.111111  13.444444
# 2          3061.250000  19.750000
# 3          5142.500000   0.500000
# 4         10889.000000  23.000000
# ...                ...        ...
# 377        1100.000000   6.000000
# 381         115.000000   0.000000
# 393        3519.000000   8.000000
# 400        2025.000000   3.000000
# 534         674.000000   0.000000
#
# [74 rows x 2 columns]

# %%
data["TEAM"].value_counts()
# Out:
# CSK      14
# RCB+     12
# KKR+     12
# DD+      10
# DC+      10
# RR+       9
# RCB       9
# DC        7
# KXIP+     7
# MI        6
# DD        6
# MI+       6
# RR        6
# CSK+      5
# KKR       5
# KXIP      5
# KXI+      1
# Name: TEAM, dtype: int64

# %%
data.groupby("TEAM")["TEAM"].count()
#grouped data
# Out:
# TEAM
# CSK      14
# CSK+      5
# DC        7
# DC+      10
# DD        6
# DD+      10
# KKR       5
# KKR+     12
# KXI+      1
# KXIP      5
# KXIP+     7
# MI        6
# MI+       6
# RCB       9
# RCB+     12
# RR        6
# RR+       9
# Name: TEAM, dtype: int64

# %%
#displaying according to sorted column
data.sort_values(by="AGE", ascending=True)

#can also do data.sort_values(by=["AGE", "TEAM", "WKTS"], ascending=True)
# Out:
#     Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 76      77       Ojha, PP    1     IND   DC+       Bowler      70      62
# 88      89      Raina, SK    1     IND   CSK      Batsman     710      13
# 65      66      Mithun, A    1     IND   RCB       Bowler     120       9
# 95      96      Sharma, I    1     IND  KKR+       Bowler     432     133
# 39      40     Jadeja, RA    1     IND   RR+   Allrounder       0       0
# ..     ...            ...  ...     ...   ...          ...     ...     ...
# 27      28      Gibbs, HH    3      SA    DC      Batsman    6167       0
# 98      99  Shoaib Akhtar    3     PAK   KKR       Bowler     544     178
# 25      26    Ganguly, SC    3     IND  KKR+      Batsman    7212      32
# 86      87    Ponting, RT    3     AUS   KKR      Batsman   13218       5
# 28      29  Gilchrist, AC    3     AUS   DC+    W. Keeper    5570       0
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# ...

# %%
data[data["TEAM"] == "CSK"]
#Only CSK members
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 3         4      Ashwin, R    1     IND  CSK       Bowler     284      31
# 4         5   Badrinath, S    2     IND  CSK      Batsman      63       0
# 5         6     Bailey, GJ    2     AUS  CSK      Batsman       0       0
# 7         8  Bollinger, DE    2     AUS  CSK       Bowler      54      50
# 15       16      Dhoni, MS    2     IND  CSK    W. Keeper    3509       0
# 22       23    Fleming, SP    3      NZ  CSK      Batsman    7172       0
# 23       24    Flintoff, A    2     ENG  CSK   Allrounder    3845     226
# 32       33     Hayden, ML    3     AUS  CSK      Batsman    8625       0
# 38       39    Hussey, MEK    3     AUS  CSK      Batsman    5708       7
# 67       68     Morkel, JA    2      SA  CSK   Allrounder      58       1
# 74       75       Ntini, M    2      SA  CSK       Bowler     699     390
# 88       89      Raina, SK    1     IND  CSK      Batsman     710      13
# ...

# %%
data[data["COUNTRY"] == "AUS"]
#Only Australian players
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 5         6      Bailey, GJ    2     AUS    CSK      Batsman       0       0
# 7         8   Bollinger, DE    2     AUS    CSK       Bowler      54      50
# 28       29   Gilchrist, AC    3     AUS    DC+    W. Keeper    5570       0
# 31       32      Harris, RJ    2     AUS    DC+       Bowler     199      46
# 32       33      Hayden, ML    3     AUS    CSK      Batsman    8625       0
# 34       35   Henriques, MC    1     AUS   KKR+   Allrounder       0       0
# 35       36       Hodge, BJ    3     AUS   KKR+      Batsman     503       0
# 36       37       Hopes, JR    2     AUS   KXIP   Allrounder       0       0
# 37       38      Hussey, DJ    2     AUS   KKR+   Allrounder       0       0
# 38       39     Hussey, MEK    3     AUS    CSK      Batsman    5708       7
# 49       50      Katich, SM    3     AUS   KXIP      Batsman    4188      21
# ...

# %%
#creating dataframes
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3
